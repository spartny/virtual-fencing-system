# %%
from ultralytics import YOLO
from PIL import Image

# %%
model = YOLO("yolov8m.pt")

# %%
img = "Images\\exported frames\\frame_210.jpg"
results = model.predict(img)
result = results[0]
print(result)
# Out:
# image 1/1 d:\Documents\code\Virtual-Fencing-Home-Security-System\Images\exported frames\frame_210.jpg: 384x640 (no detections), 281.0ms
# Speed: 2.0ms preprocess, 281.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
Image.fromarray(result.plot()[:,:, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>
