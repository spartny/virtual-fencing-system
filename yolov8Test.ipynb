# %%
from ultralytics import YOLO
from PIL import Image

# %%
model = YOLO("yolov8x.pt")

# %%
results = model.predict('cat.jpeg')
result = results[0]
print(results)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-cfa011e0718e> in <module>
# ----> 1 results = model.predict('cat.jpeg')
#       2 result = results[0]
#       3 print(results)
#
# c:\Users\parth\anaconda3\lib\site-packages\ultralytics\engine\model.py in predict(self, source, stream, predictor, **kwargs)
#     437         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     438             self.predictor.set_prompts(prompts)
# --> 439         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     440
#     441     def track(
#
# c:\Users\parth\anaconda3\lib\site-packages\ultralytics\engine\predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     166             return self.stream_inference(source, model, *args, **kwargs)
#     167         else:
# ...

# %%
Image.fromarray(result.plot()[:,:, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=226x223 at 0x12CA864EF10>
